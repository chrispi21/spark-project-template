# %%
from pyspark.sql import SparkSession
spark = (
    SparkSession.builder
    .master("local")
    .appName("load-sample-data")    
    .getOrCreate()
)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/24 14:25:10 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
df = spark.read.format("csv").option("header", True).load("file:///home/jovyan/data/sample.csv")
df.write.format("parquet").mode("overwrite").save("s3a://warehouse/sample")

# %%
spark.read.format("parquet").load("s3a://warehouse/sample").show()
# Out:
# +----+----+
# |col1|col2|
# +----+----+
# |val1| 123|
# +----+----+
